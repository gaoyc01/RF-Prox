# %%
# antenna_in

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages

save_root = 'img'
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

n_groups = 3

zero_acc = (0.676, 0.922, 0.923)
few_acc = tuple(np.array((0.805, 0.986, 0.996)) - np.array(zero_acc))

zero_ndcg = (0.853, 0.955,0.953 )
few_ndcg = tuple(np.array((0.867, 0.971, 0.975)) - np.array(zero_ndcg))

font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
fig, ax = plt.subplots(figsize=(3.5, 3))
ax2 = ax.twinx()
pp = PdfPages(save_root + '/antenna_in.pdf')

index = np.arange(n_groups)
bar_width = 0.3
interval = 0.1
left_interval = - 0.2
right_interval = 0.2

opacity = 1
error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"

rects1 = ax.bar(index + interval + bar_width + left_interval, zero_acc, bar_width,
                color="#FFFFFF",
                # edgecolor=,
                edgecolor=acc_color,
                hatch='/' * 3,
                lw=2)

rects11 = ax.bar(index + interval + bar_width + left_interval, few_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=zero_acc)       

rects2 = ax2.bar(index + interval + bar_width + right_interval, zero_ndcg, bar_width,
                color="#FFFFFF",
                
                # edgecolor=,
                edgecolor=ndcg_color,
                hatch='/' * 3,
                lw=2)    

rects22 = ax2.bar(index + interval + bar_width + right_interval, few_ndcg, bar_width,
                color="#FFFFFF",
                #edgecolor="#82B0D2",
                edgecolor=ndcg_color,
                linestyle='--',
                hatch='' * 3,
                lw=2,
                bottom=zero_ndcg)    

zeros = (-10, -10, -10)
rects3 = ax2.bar(index + interval + bar_width + left_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='/' * 3,
                lw=2,
                label='PT')
rects33 = ax2.bar(index + interval + bar_width + right_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                linestyle='--',
                hatch='' * 3,
                lw=2,
                label='FT') 


ax.set_xlabel('Antenna Num', fontproperties=font, verticalalignment='center')
ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color = acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = '#B11600')
ax.set_xticks(index + bar_width + interval)
ax.set_xticklabels(('2x3', '3x3', '3x4'))
ax.set_ylim(0.6, 1.04)
ax2.set_ylim(0.8, 1.02)
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)

for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
    
# leg = fig.legend(loc='upper center',bbox_to_anchor=(0.4,0.94), prop={'size': 7.6},ncol=2)
leg = fig.legend(loc='upper center',bbox_to_anchor=(0.28,0.92), prop={'size':9},ncol=1)


    
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)

fig.tight_layout()
# plt.show()
plt.savefig(save_root + '/antenna_in.png', dpi=800)
pp.savefig()
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
# antenna_out

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages

save_root = 'img'
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

n_groups = 3

zero_acc = (0.889, 0.911, 0.918)
few_acc = tuple(np.array((0.913, 0.921, 0.923)) - np.array(zero_acc))

zero_ndcg = (0.947, 0.955, 0.961)
few_ndcg = tuple(np.array((0.959, 0.959, 0.956)) - np.array(zero_ndcg))

font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
fig, ax = plt.subplots(figsize=(3.5, 3))
ax2 = ax.twinx()
pp = PdfPages(save_root + '/antenna_out.pdf')

index = np.arange(n_groups)
bar_width = 0.3
interval = 0.1
left_interval = - 0.2
right_interval = 0.2

opacity = 1
error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"

rects1 = ax.bar(index + interval + bar_width + left_interval, zero_acc, bar_width,
                color="#FFFFFF",
                # edgecolor=,
                edgecolor=acc_color,
                hatch='/' * 3,
                lw=2)

rects11 = ax.bar(index + interval + bar_width + left_interval, few_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=zero_acc)       

rects2 = ax2.bar(index + interval + bar_width + right_interval, zero_ndcg, bar_width,
                color="#FFFFFF",
                
                # edgecolor=,
                edgecolor=ndcg_color,
                hatch='/' * 3,
                lw=2)    

rects22 = ax2.bar(index + interval + bar_width + right_interval, few_ndcg, bar_width,
                color="#FFFFFF",
                #edgecolor="#82B0D2",
                edgecolor=ndcg_color,
                linestyle='--',
                hatch='' * 3,
                lw=2,
                bottom=zero_ndcg)    

zeros = (-10, -10, -10)
rects3 = ax2.bar(index + interval + bar_width + left_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='/' * 3,
                lw=2,
                label='PT')
rects33 = ax2.bar(index + interval + bar_width + right_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                linestyle='--',
                hatch='' * 3,
                lw=2,
                label='FT') 


ax.set_xlabel('Antenna Num', fontproperties=font, verticalalignment='center')
ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color = acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = '#B11600')
ax.set_xticks(index + bar_width + interval)
ax.set_xticklabels(('1x16', '2x16', '4x16'))
ax.set_ylim(0.85, 0.979)
ax2.set_ylim(0.88, 0.9738)
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)

for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
    
# leg = fig.legend(loc='upper center',bbox_to_anchor=(0.4,0.94), prop={'size': 7.6},ncol=2)
leg = fig.legend(loc='upper center',bbox_to_anchor=(0.4,0.947), prop={'size':9},ncol=2)


    
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)

fig.tight_layout()
# plt.show()
plt.savefig(save_root + '/antenna_out.png', dpi=800)
pp.savefig()
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib
import matplotlib.pyplot as plt
import scipy.io as scio
import os;
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# Define the input and output directories;
data_root = 'data'
save_root = 'img'
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"

font = FontProperties(fname=r"./font/Helvetica.ttf", size=13)

fig, ax = plt.subplots(figsize=(6, 3))
pp = PdfPages(save_root + './Category_in.pdf')
ax2 = ax.twinx()
# Path length data 5 10 15 20
path_length = np.array([2, 3, 4, 5, 6, 7, 8, 9])

# Wi-Drone error with path length.
w_err = np.array([0.932,0.932,0.933,0.936,0.941,0.948,0.955,0.972])
w_err_std = np.array([0.001,0.002,0.003,0.002,0.004,0.004,0.007,0.006])

ax2.plot(path_length, w_err, '-', color = ndcg_color, marker = '^')
ax2.fill_between(path_length, w_err - w_err_std, w_err + w_err_std, alpha = 0.2, color = ndcg_color)

# VO error with path length.
vo_err = np.array([0.939,0.940,0.942,0.948,0.950,0.957,0.971,0.997])
vo_err_std = np.array([0.001,0.003,0.002,0.001,0.004,0.006,0.005,0.004])

ax2.plot(path_length, vo_err, '--', color = ndcg_color, marker = '^')
ax2.fill_between(path_length, vo_err - vo_err_std, vo_err + vo_err_std, alpha = 0.2, color = ndcg_color)


# Wi-Drone error with path length.
w1_err = np.array([0.864,0.865,0.871,0.878,0.893,0.914,0.922,0.943])
w1_err_std = np.array([0.007,0.007,0.009,0.006,0.010,0.015,0.013,0.011])

ax.plot(path_length, w1_err, '-', color = acc_color, marker = '^')
ax.fill_between(path_length, w1_err - w1_err_std, w1_err + w1_err_std, alpha = 0.2, color = acc_color)

# VO error with path length.

vo1_err = np.array([0.946,0.954,0.958,0.974,0.973,0.973,0.986,0.995])
vo1_err_std = np.array([0.007,0.008,0.007,0.008,0.011,0.014,0.012,0.008])

ax.plot(path_length, vo1_err, '--', color = acc_color, marker = '^')
ax.fill_between(path_length, vo1_err - vo1_err_std, vo1_err + vo1_err_std, alpha = 0.2, color = acc_color)

zeros = np.zeros([8])
ax2.plot(path_length, zeros, '--', color = gray_color, marker = '^', label = 'FT')
ax2.plot(path_length, zeros, '-', color = gray_color, marker = '^', label = 'PT')


ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color = acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = '#B11600')
ax.set_xticks(path_length)
ax.set_xticklabels(('9', '8', '7','6','5','4','3','2'))
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(12)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(12)

        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
ax.grid(linestyle='--', linewidth=0.5, zorder=0)
plt.xlim(2, 9)
ax.set_ylim(0.8, 1)
ax2.set_ylim(0.92,1)
# plt.xticks(('15', '20', '25', '30', 'infty'))
ax.set_xlabel('Category Num', fontproperties=font, verticalalignment='top')
# plt.ylabel('Location Error (m)', fontproperties=font, verticalalignment='bottom')
leg = fig.legend(loc='upper left', prop={'size': 11},ncol =2,bbox_to_anchor=(0.575,0.36))
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)

plt.tight_layout()
# plt.show()
pp.savefig()
plt.savefig(save_root + './Category_in.png', dpi=800)
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
##### import numpy as np
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib
import matplotlib.pyplot as plt
import scipy.io as scio
import os;
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# Define the input and output directories;
data_root = 'data'
save_root = 'img'
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"

font = FontProperties(fname=r"./font/Helvetica.ttf", size=13)

fig, ax = plt.subplots(figsize=(6, 3))
pp = PdfPages(save_root + './Category_out.pdf')
ax2 = ax.twinx()
# Path length data 5 10 15 20
path_length = np.array([2, 3, 4, 5, 6, 7, 8, 9])

# Wi-Drone error with path length.
w_err = np.array([0.937,0.938,0.937,0.938,0.939,0.939,0.947,0.955])
w_err_std = np.array([0.001,0.002,0.002,0.003,0.003,0.005,0.005,0.010])

ax2.plot(path_length, w_err, '-', color = ndcg_color, marker = '^')
ax2.fill_between(path_length, w_err - w_err_std, w_err + w_err_std, alpha = 0.2, color = ndcg_color)

# VO error with path length.
vo_err = np.array([0.951,0.951,0.951,0.949,0.952,0.954,0.959,0.965])
vo_err_std = np.array([0.001,0.002,0.002,0.003,0.002,0.004,0.006,0.008])

ax2.plot(path_length, vo_err, '--', color = ndcg_color, marker = '^')
ax2.fill_between(path_length, vo_err - vo_err_std, vo_err + vo_err_std, alpha = 0.2, color = ndcg_color)


# Wi-Drone error with path length.
w1_err = np.array([0.810,0.832,0.833,0.841,0.866,0.867,0.889,0.910])
w1_err_std = np.array([0.010,0.023,0.018,0.017,0.018,0.017,0.021,0.020])

ax.plot(path_length, w1_err, '-', color = acc_color, marker = '^')
ax.fill_between(path_length, w1_err - w1_err_std, w1_err + w1_err_std, alpha = 0.2, color = acc_color)

# VO error with path length.
vo1_err = np.array([0.876,0.870,0.883,0.875,0.889,0.897,0.913,0.930])
vo1_err_std = np.array([0.015,0.013,0.019,0.021,0.020,0.019,0.012,0.015])

ax.plot(path_length, vo1_err, '--', color = acc_color, marker = '^')
ax.fill_between(path_length, vo1_err - vo1_err_std, vo1_err + vo1_err_std, alpha = 0.2, color = acc_color)

zeros = np.zeros([8])
ax2.plot(path_length, zeros, '--', color = gray_color, marker = '^', label = 'FT')
ax2.plot(path_length, zeros, '-', color = gray_color, marker = '^', label = 'PT')


ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color = acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = '#B11600')
ax.set_xticks(path_length)
ax.set_xticklabels(('9', '8', '7','6','5','4','3','2'))
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(12)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(12)

        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
ax.grid(linestyle='--', linewidth=0.5, zorder=0)
plt.xlim(2, 9)
ax.set_ylim(0.8, 0.94)
ax2.set_ylim(0.93,0.99)
# plt.xticks(('15', '20', '25', '30', 'infty'))
ax.set_xlabel('Category Num', fontproperties=font, verticalalignment='top')
# plt.ylabel('Location Error (m)', fontproperties=font, verticalalignment='bottom')
leg = fig.legend(loc='upper left', prop={'size': 11},ncol =2,bbox_to_anchor=(0.13,0.92))
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)

plt.tight_layout()
# plt.show()
pp.savefig()
plt.savefig(save_root + './Category_out.png', dpi=800)
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
data_root = 'data'
save_root = 'img'
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

n_groups = 3

in_acc = (0.772,0.832,0.922)
out_acc = (0.748,0.806,0.889)
in_ndcg = (0.898,0.922,0.955)
out_ndcg = (0.885,0.911,0.947)



fin_acc =  np.array((0.802,0.873,0.986))-in_acc
fout_acc = np.array((0.781,0.856,0.913))-out_acc 
fin_ndcg = np.array((0.905,0.932,0.971))-in_ndcg 
fout_ndcg =np.array((0.901,0.925,0.959))-out_ndcg


font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
fig, ax = plt.subplots(figsize=(4, 2.5))
ax2 = ax.twinx()
pp = PdfPages(save_root + '/module_with_spotfi_mdtrack.pdf')

index = np.arange(n_groups)
bar_width = 0.13
interval = 0.1
left_interval = - 0.3
left1_interval = - 0.1

right_interval = 0.1
right1_interval = 0.3

opacity = 1
error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

rects1 = ax.bar(index + interval + bar_width + left_interval, in_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='/' * 2,
                lw=2)

rects1a = ax.bar(index + interval + bar_width + left_interval, fin_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=in_acc) 

rects11 = ax.bar(index + interval + bar_width+ left1_interval, out_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='x' * 3,
                lw=2)
rects11a = ax.bar(index + interval + bar_width + left1_interval, fout_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=out_acc) 
   
rects2 = ax2.bar(index + interval + bar_width + right_interval, in_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='/' * 2,
                lw=2)    
rects2a = ax2.bar(index + interval + bar_width + right_interval, fin_ndcg, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=ndcg_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=in_ndcg) 
rects22 = ax2.bar(index + interval + bar_width + right1_interval, out_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='x' * 3,
                lw=2)    
rects22a = ax2.bar(index + interval + bar_width + right1_interval, fout_ndcg, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=ndcg_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=out_ndcg) 


zeros = np.zeros(n_groups)
rects3 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='/' * 2,
                lw=2,
                label = 'Wi-Fi')   

rects33 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='x' * 3,
                lw=2,
                label = 'Cellular')   


# ax.set_xlabel('Algorithms', fontproperties=font, verticalalignment='center')
ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color =acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = ndcg_color)
ax.set_xticks(index + bar_width + interval)
ax.set_xticklabels(('SpotFi', 'mD-Track','RF-Prox'))
ax.set_ylim(0.6, 1)
ax2.set_ylim(0.7, 1)
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
    
leg = fig.legend(loc='upper center',bbox_to_anchor=(0.39,0.91), prop={'size': 9},ncol=2)
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)
fig.tight_layout()
fig.tight_layout()
# plt.show()
plt.savefig(save_root + '/module_with_spotfi_mdtrack.png', dpi=800)
pp.savefig()
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
data_root = 'data'
save_root = 'img'
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

n_groups = 3

in_acc = (0.915,0.776,0.922)
out_acc = (0.853,0.840,0.889)
in_ndcg = (0.92,0.933,0.955)
out_ndcg = (0.926,0.928,0.947)

font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
fig, ax = plt.subplots(figsize=(4, 2.5))
ax2 = ax.twinx()
pp = PdfPages(save_root + '/module_with_cnn_trans.pdf')

index = np.arange(n_groups)
bar_width = 0.13
interval = 0.1
left_interval = - 0.3
left1_interval = - 0.1

right_interval = 0.1
right1_interval = 0.3

opacity = 1
error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

rects1 = ax.bar(index + interval + bar_width + left_interval, in_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='/' * 2,
                lw=2)
rects11 = ax.bar(index + interval + bar_width+ left1_interval, out_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='x' * 3,
                lw=2)
   
rects2 = ax2.bar(index + interval + bar_width + right_interval, in_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='/' * 2,
                lw=2)    
rects22 = ax2.bar(index + interval + bar_width + right1_interval, out_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='x' * 3,
                lw=2)    


zeros = np.zeros(n_groups)
rects3 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='/' * 2,
                lw=2,
                label = 'Wi-Fi')   

rects33 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='x' * 3,
                lw=2,
                label = 'Cellular')   


# ax.set_xlabel('Algorithms', fontproperties=font, verticalalignment='center')
ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color =acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = ndcg_color)
ax.set_xticks(index + bar_width + interval)
ax.set_xticklabels(('MRSE', 'Transformer', 'MRSTE'))
ax.set_ylim(0.6, 1)
ax2.set_ylim(0.6, 1)
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
    
leg = fig.legend(loc='upper center',bbox_to_anchor=(0.393,0.93), prop={'size': 9},ncol=2)
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)
fig.tight_layout()
fig.tight_layout()
# plt.show()
plt.savefig(save_root + '/module_with_cnn_trans.png', dpi=800)
pp.savefig()
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
data_root = 'data'
save_root = 'img'
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

n_groups = 4

in_acc =   np.array((0.844, 0.909, 0.908,0.922))
out_acc =  np.array((0.539, 0.568, 0.753,0.889))
in_ndcg =  np.array((0.920, 0.944, 0.951,0.955))
out_ndcg = np.array((0.784, 0.8, 0.884,0.947))

fin_acc =  np.array((0.983, 0.998, 0.989,0.986))-in_acc
fout_acc = np.array((0.652, 0.771, 0.826,0.913))-out_acc 
fin_ndcg = np.array((0.951, 0.973, 0.975,0.971))-in_ndcg 
fout_ndcg =np.array((0.843, 0.892, 0.919,0.959))-out_ndcg



font = FontProperties(fname=r"./font/Helvetica.ttf", size=13)
fig, ax = plt.subplots(figsize=(6, 3))
ax2 = ax.twinx()
pp = PdfPages(save_root + '/SNR.pdf')

index = np.arange(n_groups)
bar_width = 0.13
interval = 0.1
left_interval = - 0.3
left1_interval = - 0.1

right_interval = 0.1
right1_interval = 0.3

opacity = 1
error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

rects1 = ax.bar(index + interval + bar_width + left_interval, in_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='/' * 2,
                lw=2)
rects11 = ax.bar(index + interval + bar_width + left_interval, fin_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=in_acc) 
rects2 = ax.bar(index + interval + bar_width+ left1_interval, out_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='x' * 3,
                lw=2)
rects22 = ax.bar(index + interval + bar_width + left1_interval, fout_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=out_acc) 
rects3 = ax2.bar(index + interval + bar_width + right_interval, in_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='/' * 2,
                lw=2)    
rects33 = ax2.bar(index + interval + bar_width + right_interval, fin_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='' * 2, 
                linestyle='--',
                lw=2,
                bottom=in_ndcg)  
rects4 = ax2.bar(index + interval + bar_width + right1_interval, out_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='x' * 3,
                lw=2)    
rects44 = ax2.bar(index + interval + bar_width + right1_interval, fout_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='' * 2,
                lw=2,
                linestyle='--',
                bottom=out_ndcg)  


zeros = np.zeros(n_groups)
rects5 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='/' * 2,
                lw=2,
                label = 'PT Wi-Fi')   

rects6 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='x' * 3,
                lw=2,
                label = 'PT Cellular')   
rects7 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                label = 'FT')  


ax.set_xlabel('SNR(dB)', fontproperties=font, verticalalignment='center')
ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color =acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = ndcg_color)
ax.set_xticks(index + bar_width + interval)
ax.set_xticklabels(('15', '20', '25', '30'))
ax.set_ylim(0.5, 1.08)
ax2.set_ylim(0.75, 1.04)
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(12)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(12)
    
        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
    
leg = fig.legend(loc='upper center',bbox_to_anchor=(0.492,0.96), prop={'size': 10},ncol=3)
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)
fig.tight_layout()
fig.tight_layout()
# plt.show()
plt.savefig(save_root + '/SNR.png', dpi=800)
pp.savefig()
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
data_root = 'data'
save_root = 'img'
# acc_color = "#1D485D"
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

n_groups = 2

in_acc = np.array((0.922, 0.721))
out_acc = np.array((0.889, 0.864))
in_ndcg = np.array((0.955, 0.898))
out_ndcg = np.array((0.947, 0.940))

fin_acc = np.array((0.986, 0.782))  -in_acc
fout_acc = np.array((0.913, 0.889)) -out_acc 
fin_ndcg = np.array((0.971, 0.867)) -in_ndcg 
fout_ndcg = np.array((0.959, 0.948))-out_ndcg



font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
fig, ax = plt.subplots(figsize=(4, 2.5))
ax2 = ax.twinx()
pp = PdfPages(save_root + '/cos_mlp.pdf')

index = np.arange(n_groups)
bar_width = 0.13
interval = 0.1
left_interval = - 0.3
left1_interval = - 0.1

right_interval = 0.1
right1_interval = 0.3

opacity = 1
error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

rects1 = ax.bar(index + interval + bar_width + left_interval, in_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='/' * 2,
                lw=2)
rects11 = ax.bar(index + interval + bar_width + left_interval, fin_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=in_acc) 
rects2 = ax.bar(index + interval + bar_width+ left1_interval, out_acc, bar_width,
                color="#FFFFFF",
                edgecolor=acc_color,
                hatch='x' * 3,
                lw=2)
rects22 = ax.bar(index + interval + bar_width + left1_interval, fout_acc, bar_width,
                color="#FFFFFF",
                # edgecolor="#FFBE7A",
                edgecolor=acc_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                bottom=out_acc) 
rects3 = ax2.bar(index + interval + bar_width + right_interval, in_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='/' * 2,
                lw=2)    
rects33 = ax2.bar(index + interval + bar_width + right_interval, fin_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='' * 2, 
                linestyle='--',
                lw=2,
                bottom=in_ndcg)  
rects4 = ax2.bar(index + interval + bar_width + right1_interval, out_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='x' * 3,
                lw=2)    
rects44 = ax2.bar(index + interval + bar_width + right1_interval, fout_ndcg, bar_width,
                color="#FFFFFF",
                edgecolor=ndcg_color,
                hatch='' * 2,
                lw=2,
                linestyle='--',
                bottom=out_ndcg)  


zeros = np.zeros(n_groups)
rects5 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='/' * 2,
                lw=2,
                label = 'PT Wi-Fi')   

rects6 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='x' * 3,
                lw=2,
                label = 'PT Cellular')   
rects7 = ax2.bar(index + interval + bar_width + right1_interval, zeros, bar_width,
                color="#FFFFFF",
                edgecolor=gray_color,
                hatch='' * 3,
                linestyle='--',
                lw=2,
                label = 'FT')  


# ax.set_xlabel('Methods', fontproperties=font, verticalalignment='center')
ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color =acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = ndcg_color)
ax.set_xticks(index + bar_width + interval)
ax.set_xticklabels(('Cosine', 'MLP'))
ax.set_ylim(0.65, 1.04)
ax2.set_ylim(0.84, 1.018)
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
    
leg = fig.legend(loc='upper center',bbox_to_anchor=(0.623,0.935), prop={'size': 9},ncol=1)
leg.get_frame().set_edgecolor('#000000')
leg.get_frame().set_linewidth(0.5)
fig.tight_layout()
fig.tight_layout()
# plt.show()
plt.savefig(save_root + '/cos_mlp.png', dpi=800)
pp.savefig()
pp.close()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib
import matplotlib.pyplot as plt
import scipy.io as scio
import os;
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# Define the input and output directories;
data_root = 'data'
save_root = 'img'
# acc_color = "#1D485D"
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"
font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
# plt.figure(figsize=(4, 2.5))
fig, ax = plt.subplots(figsize=(3.5, 3))
pp = PdfPages(save_root + './data_num_in.pdf')
ax2 = ax.twinx()

# Path length data 5 10 15 20
path_length = np.array([0, 1, 2, 3, 4, 5])

# Wi-Drone error with path length.
w_err = np.array([0.922, 0.930, 0.960, 0.981, 0.986, 0.986])
w_err_up = np.array([0.013, 0.012, 0.012,0.014, 0.012,0.007])
w_err_dn = np.array([0.013, 0.012, 0.012,0.014, 0.012,0.007])

ax.plot(path_length, w_err, '-', color = acc_color, marker = '^')
# ax.plot(path_length, w_err, '.', color = 'tab:blue', markersize = 8)
ax.fill_between(path_length, w_err - w_err_dn, w_err + w_err_up, alpha = 0.2,color = acc_color)

# IMU error with path length.
imu_err = np.array([0.955, 0.961, 0.968,0.971, 0.971,0.972])
imu_err_up = np.array([0.007, 0.005, 0.004,0.007, 0.005, 0.005])
imu_err_dn = np.array([0.007, 0.005, 0.004,0.007, 0.005, 0.005])

ax2.plot(path_length, imu_err, '-', color =ndcg_color, marker = '^')
# ax2.plot(path_length, imu_err, '.', color = 'tab:orange', markersize = 10)
ax2.fill_between(path_length, imu_err - imu_err_dn, imu_err + imu_err_up, alpha = 0.2, color = ndcg_color)



ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color = acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = ndcg_color)
ax.set_xticklabels(('0','25', '50', '75','100','125'))
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
ax.grid(linestyle='--', linewidth=0.5, zorder=0)
plt.xlim(0, 5)
ax.set_ylim(0.9, 1)
ax2.set_ylim(0.95, 1)

ax.set_xlabel('Data Volume', fontproperties=font, verticalalignment='top')
# plt.ylabel('Location Error (m)', fontproperties=font, verticalalignment='bottom')

plt.tight_layout()
# plt.show()
pp.savefig()
plt.savefig(save_root + './data_num_in.png', dpi=800)
pp.close()
# Out:
# C:\Users\73473\AppData\Local\Temp\ipykernel_8592\2747741671.py:48: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(('0','25', '50', '75','100','125'))
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
import numpy as np
from matplotlib.font_manager import FontProperties
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib
import matplotlib.pyplot as plt
import scipy.io as scio
import os;
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
# Define the input and output directories;
data_root = 'data'
save_root = 'img'
acc_color = "#1D485D"
ndcg_color = "#B11600"
gray_color = "#525252"
font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
# plt.figure(figsize=(4, 2.5))
fig, ax = plt.subplots(figsize=(3.5, 3))
pp = PdfPages(save_root + './data_num_out.pdf')
ax2 = ax.twinx()

# Path length data 5 10 15 20
path_length = np.array([0, 1, 2, 3, 4, 5])

# Wi-Drone error with path length.
w_err = np.array([0.889, 0.892, 0.899, 0.903, 0.913,0.912])
w_err_up = np.array([0.021, 0.022, 0.013,0.028, 0.012,0.021])
w_err_dn = np.array([0.021, 0.022, 0.013,0.028, 0.012,0.021])

ax.plot(path_length, w_err, '-', color = acc_color, marker = '^')
# ax.plot(path_length, w_err, '.', color = 'tab:blue', markersize = 8)
ax.fill_between(path_length, w_err - w_err_dn, w_err + w_err_up, alpha = 0.2,color = acc_color)

# IMU error with path length.
imu_err = np.array([0.947, 0.952, 0.952,0.953, 0.959,0.957])
imu_err_up = np.array([0.005, 0.004, 0.005,0.008, 0.006,0.006])
imu_err_dn = np.array([0.005, 0.004, 0.005,0.008, 0.006,0.006])

ax2.plot(path_length, imu_err, '-', color =ndcg_color, marker = '^')
# ax2.plot(path_length, imu_err, '.', color = 'tab:orange', markersize = 10)
ax2.fill_between(path_length, imu_err - imu_err_dn, imu_err + imu_err_up, alpha = 0.2, color = ndcg_color)


ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center',color = acc_color)
ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center',color = ndcg_color)
ax.set_xticklabels(('0','250', '500', '750','1000','1250'))
# Set ticks grids and labels
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
for label in (ax2.get_xticklabels() + ax2.get_yticklabels()):
    label.set_fontproperties(font)
    label.set_fontsize(11)
    
        
for label in (ax.get_yticklabels()):
    label.set_color(acc_color)
for label in (ax2.get_yticklabels()):
    label.set_color(ndcg_color)
ax.grid(linestyle='--', linewidth=0.5, zorder=0)
plt.xlim(0, 5)
ax.set_ylim(0.82, 0.94)
ax2.set_ylim(0.94, 0.98)

ax.set_xlabel('Data Volume', fontproperties=font, verticalalignment='top')
# plt.ylabel('Location Error (m)', fontproperties=font, verticalalignment='bottom')

plt.tight_layout()
# plt.show()
pp.savefig()
plt.savefig(save_root + './data_num_out.png', dpi=800)
pp.close()
# Out:
# C:\Users\73473\AppData\Local\Temp\ipykernel_8592\2512223515.py:46: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(('0','250', '500', '750','1000','1250'))
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# meta NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.ticker as mtick
# from matplotlib.ticker import MaxNLocator
# from collections import namedtuple
# from matplotlib.font_manager import FontProperties
# from matplotlib.backends.backend_pdf import PdfPages
# data_root = 'data'
# save_root = 'img'

# import matplotlib
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42

# n_groups = 4

# zero_acc = (0.907, 0.919, 0.956, 0.975)
# few_acc = tuple(np.array((0.985, 0.985, 0.989,0.995)) - np.array(zero_acc))

# zero_ndcg = (0.895, 0.902, 0.953,0.971)
# few_ndcg = tuple(np.array((0.958, 0.963, 0.976,0.985)) - np.array(zero_ndcg))

# font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
# fig, ax = plt.subplots(figsize=(4, 2.5))
# # ax2 = ax.twinx()
# pp = PdfPages(save_root + '/accum_bar_acc.pdf')

# index = np.arange(n_groups)
# bar_width = 0.3
# interval = 0.1
# left_interval = - 0.2
# right_interval = 0.2

# opacity = 1
# error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

# color_list =['#FFBE7A',"#82B0D2"] 

# rects1 = ax.bar(index + interval + bar_width + left_interval, zero_acc, bar_width,
#                 color="#FFFFFF",
#                 # edgecolor=,
#                 edgecolor="tab:blue",
#                 hatch='/' * 3,
#                 lw=2,
#                 label='Real Zero')

# rects11 = ax.bar(index + interval + bar_width + left_interval, few_acc, bar_width,
#                 color="#FFFFFF",
#                 # edgecolor="#FFBE7A",
#                 edgecolor="tab:blue",
#                 hatch='' * 3,
#                 linestyle='--',
#                 lw=2,
#                 bottom=zero_acc,
#                 label='Real Few')       

# rects2 = ax.bar(index + interval + bar_width + right_interval, zero_ndcg, bar_width,
#                 color="#FFFFFF",
                
#                 # edgecolor=,
#                 edgecolor="tab:orange",
#                 hatch='x' * 3,
#                 lw=2,
#                 label='Real Zero')    

# rects22 = ax.bar(index + interval + bar_width + right_interval, few_ndcg, bar_width,
#                 color="#FFFFFF",
#                 #edgecolor="#82B0D2",
#                 edgecolor="tab:orange",
#                 linestyle='--',
#                 hatch='' * 3,
#                 lw=2,
#                 bottom=zero_ndcg,
#                 label='Real Few')    


# ax.set_xlabel('Category Num', fontproperties=font, verticalalignment='center')
# ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center')
# # ax2.set_ylabel('Real Acc', fontproperties=font, verticalalignment='center')
# ax.set_xticks(index + bar_width + interval)
# ax.set_xticklabels(('5', '4', '3','2'))
# ax.set_ylim(0.85, 1.03)
# # ax2.set_ylim(0.85, 1.03)
# # Set ticks grids and labels
# for label in (ax.get_xticklabels() + ax.get_yticklabels()):
#     label.set_fontproperties(font)
#     label.set_fontsize(10)
# leg = fig.legend(loc='upper center',bbox_to_anchor=(0.41,0.945), prop={'size': 7.6},ncol=2)

# leg.get_frame().set_edgecolor('#000000')
# leg.get_frame().set_linewidth(0.5)
# fig.tight_layout()
# fig.tight_layout()
# # plt.show()
# plt.savefig(save_root + '/accum_bar_acc.png', dpi=800)
# pp.savefig()
# pp.close()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib.ticker as mtick
# from matplotlib.ticker import MaxNLocator
# from collections import namedtuple
# from matplotlib.font_manager import FontProperties
# from matplotlib.backends.backend_pdf import PdfPages
# data_root = 'data'
# save_root = 'img'
# # red (178, 23, 0) #b21700
# # gray (65, 65, 65) #414141
# # bluegreen (49, 121, 125) #31797d
# # springgreen #a020f0
# import matplotlib
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42
# # blue (81, 157, 210) #519DD2
# # green (113, 173, 81) #71AD51 
# # red (255, 94, 92) #FF5E5C 
# # yellow (245, 182, 65) #F5B641

# n_groups = 4

# zero_acc = (0.838, 0.876, 0.909, 0.988)
# few_acc = tuple(np.array((0.878, 0.911, 0.939,0.997)) - np.array(zero_acc))

# zero_ndcg = (0.815, 0.956, 0.899,0.968)
# few_ndcg = tuple(np.array((0.844, 0.889, 0.914,0.993)) - np.array(zero_ndcg))


# font = FontProperties(fname=r"./font/Helvetica.ttf", size=12)
# fig, ax = plt.subplots(figsize=(4, 2.5))
# # ax2 = ax.twinx()
# pp = PdfPages(save_root + '/accum_bar_ndcg.pdf')

# index = np.arange(n_groups)
# bar_width = 0.3
# interval = 0.1
# left_interval = - 0.2
# right_interval = 0.2

# opacity = 1
# error_config = {'ecolor': '#666666', 'elinewidth': 1.7, 'capsize': 5}

# color_list =['#FFBE7A',"#82B0D2"] 

# rects1 = ax.bar(index + interval + bar_width + left_interval, zero_acc, bar_width,
#                 color="#FFFFFF",
#                 # edgecolor=,
#                 edgecolor="tab:blue",
#                 hatch='/' * 3,
#                 lw=2,
#                 label='Real Zero')

# rects11 = ax.bar(index + interval + bar_width + left_interval, few_acc, bar_width,
#                 color="#FFFFFF",
#                 # edgecolor="#FFBE7A",
#                 edgecolor="tab:blue",
#                 hatch='' * 3,
#                 linestyle='--',
#                 lw=2,
#                 bottom=zero_acc,
#                 label='Real Few')       

# rects2 = ax.bar(index + interval + bar_width + right_interval, zero_ndcg, bar_width,
#                 color="#FFFFFF",
                
#                 # edgecolor=,
#                 edgecolor="tab:orange",
#                 hatch='x' * 3,
#                 lw=2,
#                 label='Real Zero')    

# rects22 = ax.bar(index + interval + bar_width + right_interval, few_ndcg, bar_width,
#                 color="#FFFFFF",
#                 #edgecolor="#82B0D2",
#                 edgecolor="tab:orange",
#                 linestyle='--',
#                 hatch='' * 3,
#                 lw=2,
#                 bottom=zero_ndcg,
#                 label='Real Few')    


# ax.set_xlabel('Category Num', fontproperties=font, verticalalignment='center')
# ax.set_ylabel('NDCG', fontproperties=font, verticalalignment='center')
# # ax2.set_ylabel('Real NDCG', fontproperties=font, verticalalignment='center')
# ax.set_xticks(index + bar_width + interval)
# ax.set_xticklabels(('5', '4', '3','2'))
# ax.set_ylim(0.8, 1.007)
# # ax2.set_ylim(0.8, 1.007)
# # Set ticks grids and labels
# for label in (ax.get_xticklabels() + ax.get_yticklabels()):
#     label.set_fontproperties(font)
#     label.set_fontsize(10)
# leg = fig.legend(loc='upper center',bbox_to_anchor=(0.412,0.943), prop={'size': 7.6},ncol=2)

# leg.get_frame().set_edgecolor('#000000')
# leg.get_frame().set_linewidth(0.5)
# fig.tight_layout()
# fig.tight_layout()
# # plt.show()
# plt.savefig(save_root + '/accum_bar_ndcg.png', dpi=800)
# pp.savefig()
# pp.close()

# %%
# import numpy as np
# from matplotlib.font_manager import FontProperties
# from matplotlib.backends.backend_pdf import PdfPages
# import matplotlib
# import matplotlib.pyplot as plt
# import scipy.io as scio
# import os;
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42
# # Define the input and output directories;
# data_root = 'data'
# save_root = 'img'

# font = FontProperties(fname=r"./font/Helvetica.ttf", size=11)
# # plt.figure(figsize=(4, 2.5))
# fig, ax = plt.subplots(figsize=(4, 2.5))
# pp = PdfPages(save_root + './SNR.pdf')
# ax2 = ax.twinx()

# # Path length data 5 10 15 20
# path_length = np.array([15, 20, 25, 30,35])

# # Wi-Drone error with path length.
# w_err = np.array([0.838, 0.937, 0.949, 0.952, 0.956])
# w_err_up = np.array([0.11, 0.036, 0.028, 0.025, 0.021])
# w_err_dn = np.array([0.11, 0.036, 0.028, 0.025, 0.021])

# ax.plot(path_length, w_err, '-', color = 'tab:blue', marker = '^', label = 'Zero Acc')
# # ax.plot(path_length, w_err, '.', color = 'tab:blue', markersize = 8)
# ax.fill_between(path_length, w_err - w_err_dn, w_err + w_err_up, alpha = 0.2)

# # VO error with path length.
# vo_err = np.array([0.863, 0.961, 0.988, 0.988, 0.989])
# vo_err_up = np.array([0.097, 0.027, 0.006, 0.007, 0.005])
# vo_err_dn = np.array([0.097, 0.027, 0.006, 0.007, 0.005])

# ax.plot(path_length, vo_err, '--', color = 'tab:orange', marker = '^', label = 'Few Acc')
# # ax.plot(path_length, vo_err, '^', color = 'tab:orange', markersize = 8)
# ax.fill_between(path_length, vo_err - vo_err_dn, vo_err + vo_err_up, alpha = 0.2)

# # IMU error with path length.
# imu_err = np.array([0.903, 0.906, 0.907, 0.907, 0.909])
# imu_err_up = np.array([0.023, 0.008, 0.007, 0.006, 0.006])
# imu_err_dn = np.array([0.023, 0.008, 0.007, 0.006, 0.006])

# ax2.plot(path_length, imu_err, '-', color = 'tab:green', marker = 'o', label = 'Zero NDCG')
# # ax2.plot(path_length, imu_err, '.', color = 'tab:green', markersize = 10)
# ax2.fill_between(path_length, imu_err - imu_err_dn, imu_err + imu_err_up, alpha = 0.2, color = 'tab:green')

# # IMU error with path length.
# imu1_err = np.array([0.907, 0.909, 0.909, 0.91, 0.912])
# imu1_err_up = np.array([0.01, 0.004, 0.003, 0.004, 0.003])
# imu1_err_dn = np.array([0.01, 0.004, 0.003, 0.004, 0.003])

# ax2.plot(path_length, imu1_err, '--', color = 'tab:red', marker = 'o', label = 'Few NDCG')
# # ax2.plot(path_length, imu1_err, '.', color = 'tab:red', markersize = 10)
# ax2.fill_between(path_length, imu1_err - imu1_err_dn, imu1_err + imu1_err_up, alpha = 0.2, color = 'tab:red')


# ax.set_ylabel('Accuracy', fontproperties=font, verticalalignment='center')
# ax2.set_ylabel('NDCG', fontproperties=font, verticalalignment='center')
# ax.set_xticklabels(('15', '20', '25','30','35'))
# # Set ticks grids and labels
# for label in (ax.get_xticklabels() + ax.get_yticklabels()):
#     label.set_fontproperties(font)
#     label.set_fontsize(10)
# ax.grid(linestyle='--', linewidth=0.5, zorder=0)
# plt.xlim(15, 35)
# ax.set_ylim(0.75, 1)
# ax2.set_ylim(0.86, 0.96)
# # plt.xticks(('15', '20', '25', '30', 'infty'))
# ax.set_xlabel('SNR(dB)', fontproperties=font, verticalalignment='top')
# # plt.ylabel('Location Error (m)', fontproperties=font, verticalalignment='bottom')
# leg = fig.legend(loc='lower right', prop={'size': 9},ncol =2,bbox_to_anchor=(0.83,0.240))
# leg.get_frame().set_edgecolor('#000000')
# leg.get_frame().set_linewidth(0.5)

# plt.tight_layout()
# # plt.show()
# pp.savefig()
# plt.savefig(save_root + './SNR.png', dpi=800)
# pp.close()
